# %% [markdown]
# frist languge that sport OOP is : cpp, before cpp we use procedure
# what's procedure?
# writheting code as a sequence of steps (instructions), sometimes grouped into functions.

# %%
int add(int a, int b) {
    return a + b;
}

int main() {
    int result = add(2, 3); // call function
    cout << result;
}

# %% [markdown]
# OOP is programming paradigm based on the concept of "Object"
# A programming paradigm: is a style of programming , a way of thinking about Software Construction
